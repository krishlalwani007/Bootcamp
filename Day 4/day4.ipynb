# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = cv2.imread(r"C:\Users\admin\Desktop\1.png")

print(type(img))
print(img.shape)

# Original image
cv2.imshow("Original", img)
cv2.waitKey(0)

# Resize image
img_resize = cv2.resize(img, (400, 256))

cv2.imshow("Resized", img_resize)
cv2.waitKey(0)

# Crop image
img_crop = img[100:300, 200:500]

cv2.imshow("Cropped", img_crop)
cv2.waitKey(0)

# Close all windows
cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# (1536, 1024, 3)
