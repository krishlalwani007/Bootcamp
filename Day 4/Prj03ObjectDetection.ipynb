# %%
pip install ultralytics opencv-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.161-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: opencv-python in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (5.0.0.93)
# Requirement already satisfied: cloudpickle>=3.1.1 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ultralytics) (3.1.2)
# Collecting filelock>=3.16.1 (from ultralytics)
#   Downloading filelock-4.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from ultralytics) (2.5.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ultralytics) (3.11.2)
# Requirement already satisfied: pillow>=7.1.2 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from ultralytics) (12.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ultralytics) (2.34.2)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.14.0-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.29.0-cp314-cp314-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from ultralytics) (7.2.2)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.44.2-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.1.6 (from ultralytics)
#   Downloading ultralytics_thop-2.1.6-py3-none-any.whl.metadata (13 kB)
# Collecting ultralytics-platform>=0.1.45 (from ultralytics)
#   Downloading ultralytics_platform-0.1.62-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.3.0->ultralytics) (26.3)
# Requirement already satisfied: pyparsing>=3 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.44.2 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.44.2-cp310-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from requests>=2.23.0->ultralytics) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from torch>=1.8.0->ultralytics) (4.16.0)
# Collecting setuptools>=77.0.3 (from torch>=1.8.0->ultralytics)
#   Downloading setuptools-84.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2026.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: httpx<1,>=0.28 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from ultralytics-platform>=0.1.45->ultralytics) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (4.14.2)
# Requirement already satisfied: httpcore==1.* in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\admin\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1,>=0.28->ultralytics-platform>=0.1.45->ultralytics) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.161-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.5 MB 2.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.1 MB/s  0:00:00
# Downloading filelock-4.0.3-py3-none-any.whl (108 kB)
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
# Downloading polars-1.44.2-py3-none-any.whl (865 kB)
#    ---------------------------------------- 0.0/865.8 kB ? eta -:--:--
#    ------------------------ --------------- 524.3/865.8 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 865.8/865.8 kB 3.3 MB/s  0:00:00
# Downloading polars_runtime_32-1.44.2-cp310-abi3-win_amd64.whl (51.3 MB)
#    ---------------------------------------- 0.0/51.3 MB ? eta -:--:--
#     --------------------------------------- 0.8/51.3 MB 3.6 MB/s eta 0:00:15
#    - -------------------------------------- 1.6/51.3 MB 3.8 MB/s eta 0:00:13
#    - -------------------------------------- 2.4/51.3 MB 4.1 MB/s eta 0:00:13
#    --- ------------------------------------ 3.9/51.3 MB 4.7 MB/s eta 0:00:11
#    ---- ----------------------------------- 5.2/51.3 MB 5.0 MB/s eta 0:00:10
#    ----- ---------------------------------- 6.6/51.3 MB 5.2 MB/s eta 0:00:09
#    ------ --------------------------------- 7.9/51.3 MB 5.4 MB/s eta 0:00:08
#    ------- -------------------------------- 9.4/51.3 MB 5.7 MB/s eta 0:00:08
#    ------- -------------------------------- 10.2/51.3 MB 5.7 MB/s eta 0:00:08
#    -------- ------------------------------- 11.0/51.3 MB 5.4 MB/s eta 0:00:08
#    --------- ------------------------------ 12.1/51.3 MB 5.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 13.1/51.3 MB 5.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 14.2/51.3 MB 5.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 14.9/51.3 MB 5.2 MB/s eta 0:00:07
#    ------------ --------------------------- 16.5/51.3 MB 5.3 MB/s eta 0:00:07
#    ------------- -------------------------- 17.6/51.3 MB 5.3 MB/s eta 0:00:07
#    -------------- ------------------------- 18.4/51.3 MB 5.3 MB/s eta 0:00:07
#    --------------- ------------------------ 19.4/51.3 MB 5.2 MB/s eta 0:00:07
#    --------------- ------------------------ 20.4/51.3 MB 5.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 21.5/51.3 MB 5.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 22.8/51.3 MB 5.3 MB/s eta 0:00:06
#    ------------------ --------------------- 23.6/51.3 MB 5.2 MB/s eta 0:00:06
#    ------------------- -------------------- 24.9/51.3 MB 5.2 MB/s eta 0:00:06
#    -------------------- ------------------- 26.0/51.3 MB 5.2 MB/s eta 0:00:05
#    --------------------- ------------------ 27.0/51.3 MB 5.2 MB/s eta 0:00:05
#    ---------------------- ----------------- 28.3/51.3 MB 5.3 MB/s eta 0:00:05
#    ----------------------- ---------------- 29.9/51.3 MB 5.3 MB/s eta 0:00:05
#    ------------------------ --------------- 31.5/51.3 MB 5.4 MB/s eta 0:00:04
#    ------------------------- -------------- 33.0/51.3 MB 5.5 MB/s eta 0:00:04
#    --------------------------- ------------ 35.1/51.3 MB 5.7 MB/s eta 0:00:03
#    ---------------------------- -----------
1 MB 3.6 MB/s eta 0:00:02
#    -------------------------------------- - 120.6/124.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  122.2/124.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  123.5/124.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  124.0/124.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 124.1/124.1 MB 3.6 MB/s  0:00:34
# Downloading fsspec-2026.9.0-py3-none-any.whl (221 kB)
# Downloading setuptools-84.0.0-py3-none-any.whl (818 kB)
#    ---------------------------------------- 0.0/818.2 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/818.2 kB ? eta -:--:--
#    ---------------------------------------- 818.2/818.2 kB 2.1 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/6.3 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.1/6.3 MB 3.3 MB/s eta 0:00:02
#    --------------------- ------------------ 3.4/6.3 MB 4.4 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 5.1 MB/s  0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 2.0 MB/s  0:00:00
# Downloading torchvision-0.29.0-cp314-cp314-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------------------------------ --------- 1.0/1.4 MB 7.8 MB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.2 MB/s  0:00:00
# Downloading ultralytics_platform-0.1.62-py3-none-any.whl (90 kB)
# Downloading ultralytics_thop-2.1.6-py3-none-any.whl (30 kB)
# Installing collected packages: nvidia-ml-py, mpmath, sympy, setuptools, polars-runtime-32, fsspec, filelock, torch, polars, ultralytics-thop, ultralytics-platform, torchvision, ultralytics
#
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    --- ------------------------------------  1/13 [mpmath]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    ------------ ---------------------------  4/13 [polars-runtime-32]
#    ------------ ---------------------------  4/13 [polars-runtime-32]
#    ------------ ---------------------------  4/13 [polars-runtime-32]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    --------------- ------------------------  5/13 [fsspec]
#    ------------------ ---------------------  6/13 [filelock]
#    ------------------ ---------------------  6/13 [filelock]
#    ------------------ ---------------------  6/13 [filelock]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    ------------------------ ---------------  8/13 [polars]
#    --------------------------- ------------  9/13 [ultralytics-thop]
#    ------------------------------ --------- 10/13 [ultralytics-platform]
#    ------------------------------ --------- 10/13 [ultralytics-platform]
#    ------------------------------ --------- 10/13 [ultralytics-platform]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    --------------------------------- ------ 11/13 [torchvision]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ------------------------------------ --- 12/13 [ultralytics]
#    ---------------------------------------- 13/13 [ultralytics]
#
# Successfully installed filelock-4.0.3 fsspec-2026.9.0 mpmath-1.3.0 nvidia-ml-py-13.610.43 polars-1.44.2 polars-runtime-32-1.44.2 setuptools-84.0.0 sympy-1.14.0 torch-2.14.0 torchvision-0.29.0 ultralytics-8.4.161 ultralytics-platform-0.1.62 ultralytics-thop-2.1.6
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script isympy.exe is installed in 'C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script ul.exe is installed in 'C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ultralytics.exe and yolo.exe are installed in 'C:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import cv2
from ultralytics import settings

# Disable data and crash report tracking
settings.update({"sync": False})
from ultralytics import YOLO

# 1. Load the lightweight YOLOv8 Nano model (~6MB, runs fast on CPU)
model = YOLO('yolov8n.pt')

# 2. Open the webcam (0 is default built-in camera)
cap = cv2.VideoCapture(0)

print("Starting Object Counter... Press 'q' on the video window to quit.")

while cap.isOpened():
  success, frame = cap.read()
  if not success:
    print("Failed to grab camera frame.")
    break

  # 3. Perform object detection on the current frame
  results = model(frame, verbose=False)

  # Get total number of objects detected in this frame
  detected_count = len(results[0].boxes)

  # 4. Render detection boxes directly on the frame
  annotated_frame = results[0].plot()

  # 5. Display the object count overlay on screen
  cv2.putText(
      annotated_frame,
      f'Total Objects Counted: {detected_count}',
      (20, 50),  # Position (x, y)
      cv2.FONT_HERSHEY_SIMPLEX,
      1,  # Font scale
      (0, 255, 0),  # Text color (Green)
      2,  # Thickness
      cv2.LINE_AA,
  )

  # 6. Show the frame in a window
  cv2.imshow('BCA AI Demo - Live Object Counter', annotated_frame)

  # 7. Terminate program cleanly when pressing 'q'
  if cv2.waitKey(1) & 0xFF == ord('q'):
    print("Terminating program...")
    break

# Release camera and close all windows cleanly
cap.release()

# 2. Add short wait key loops to let Windows pump destroy events cleanly
cv2.waitKey(1)
cv2.destroyAllWindows()
cv2.waitKey(1)

print("Camera feed closed successfully.")
# Out:
# Creating new Ultralytics Settings v0.0.8 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\admin\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 3.7MB/s 1.7s.7s<0.0s1.3ss
# Starting Object Counter... Press 'q' on the video window to quit.
# Failed to grab camera frame.
# Camera feed closed successfully.
