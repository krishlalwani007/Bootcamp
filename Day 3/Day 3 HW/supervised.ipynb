# %%
# 1. Import libraries

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score


# 2. Load dataset

df = pd.read_csv("house_price_dataset.csv")

print(df.head())


# 3. Select features and target

X = df[["area_sqft", "bedrooms", "age_years", "location_score"]]

y = df["price_lakhs"]


# 4. Split data into training and testing

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training rows:", len(X_train))
print("Testing rows:", len(X_test))


# 5. Create the model

model = DecisionTreeRegressor(
    max_depth=3,
    random_state=42
)


# 6. Train the model

model.fit(X_train, y_train)

print("Model trained!")


# 7. Make predictions

y_pred = model.predict(X_test)

print("Predicted prices:")
print(y_pred)


# 8. Check model performance

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("R2 Score:", r2)


# 9. Predict price of a new house

new_house = [[1500, 3, 5, 9]]

prediction = model.predict(new_house)

print("Predicted house price:", prediction[0], "lakhs")
# Out:
#    area_sqft  bedrooms  age_years  location_score  price_lakhs
# 0        800         2         10               6           45
# 1       1000         2          8               7           55
# 2       1200         3          5               8           72
# 3       1500         3          3               9          105
# 4       1800         4          2               9          135
# Training rows: 16
# Testing rows: 4
# Model trained!
# Predicted prices:
# [ 50.66666667 110.          50.66666667  76.33333333]
# Mean Absolute Error: 12.416666666666664
# R2 Score: 0.6795256465209317
# Predicted house price: 110.0 lakhs
# c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2830: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# 1. Import libraries

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score


# 2. Load dataset

df = pd.read_csv("employee_salary_dataset.csv")

print(df.head())


# 3. Select features and target

X = df[[
    "experience_years",
    "age",
    "education_level",
    "hours_per_week"
]]

y = df["salary_lakhs"]


# 4. Split data into training and testing

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training rows:", len(X_train))
print("Testing rows:", len(X_test))


# 5. Create the model

model = DecisionTreeRegressor(
    max_depth=3,
    random_state=42
)


# 6. Train the model

model.fit(X_train, y_train)

print("Model trained!")


# 7. Make predictions

y_pred = model.predict(X_test)

print("Predicted salaries:")
print(y_pred)


# 8. Check model performance

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("R2 Score:", r2)


# 9. Predict salary for a new employee

new_employee = [[5, 30, 2, 45]]

prediction = model.predict(new_employee)

print("Predicted salary:", prediction[0], "lakhs")
# Out:
#    experience_years  age  education_level  hours_per_week  salary_lakhs
# 0                 1   22                1              40           3.2
# 1                 2   24                1              42           3.8
# 2                 3   26                2              45           4.8
# 3                 4   28                2              44           5.6
# 4                 5   30                2              46           6.8
# Training rows: 16
# Testing rows: 4
# Model trained!
# Predicted salaries:
# [ 3.25 13.85  6.8   3.25]
# Mean Absolute Error: 0.5374999999999999
# R2 Score: 0.9601324320595944
# Predicted salary: 6.8 lakhs
# c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2830: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# 1. Import libraries

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, r2_score


# 2. Load dataset

df = pd.read_csv("car_price_dataset.csv")

print(df.head())


# 3. Select features and target

X = df[[
    "car_age",
    "km_driven",
    "engine_cc",
    "mileage_kmpl",
    "owners"
]]

y = df["price_lakhs"]


# 4. Split data into training and testing

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training rows:", len(X_train))
print("Testing rows:", len(X_test))


# 5. Create the model

model = DecisionTreeRegressor(
    max_depth=3,
    random_state=42
)


# 6. Train the model

model.fit(X_train, y_train)

print("Model trained!")


# 7. Make predictions

y_pred = model.predict(X_test)

print("Predicted prices:")
print(y_pred)


# 8. Check model performance

mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("R2 Score:", r2)


# 9. Predict price of a new car

new_car = [[3, 25000, 1500, 18, 1]]

prediction = model.predict(new_car)

print("Predicted car price:", prediction[0], "lakhs")
# Out:
#    car_age  km_driven  engine_cc  mileage_kmpl  owners  price_lakhs
# 0        1      12000       1200            20       1          8.5
# 1        2      18000       1200            19       1          7.8
# 2        3      25000       1500            18       1          7.2
# 3        4      32000       1500            17       2          6.5
# 4        5      45000       1600            16       2          5.8
# Training rows: 16
# Testing rows: 4
# Model trained!
# Predicted prices:
# [9.  8.  3.8 8. ]
# Mean Absolute Error: 0.3749999999999998
# R2 Score: 0.9631950926790239
# Predicted car price: 7.233333333333333 lakhs
# c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2830: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
