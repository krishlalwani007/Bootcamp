# %%
import random

numbers = [random.randint(1, 100) for _ in range(10)]

print("List:", numbers)
print("Even numbers:", [num for num in numbers if num % 2 == 0])
# Out:
# List: [27, 56, 48, 92, 63, 59, 45, 85, 13, 66]
# Even numbers: [56, 48, 92, 66]

# %%
text = "Python is very easy"

print("Original:", text)

# Reverse the complete string
print("Reverse string:", text[::-1])

# Reverse the order of words
print("Reverse words:", " ".join(text.split()[::-1]))
# Out:
# Original: Python is very easy
# Reverse string: ysae yrev si nohtyP
# Reverse words: easy very is Python
